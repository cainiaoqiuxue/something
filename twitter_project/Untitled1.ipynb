# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation


df = pd.read_csv('res_sentiment.csv')
neg_df = df[df['sentiment'] == -1]
neu_df = df[df['sentiment'] == 0]
pos_df = df[df['sentiment'] == 1]

def topic_analysis(df, n_components, top_n):
    contents = [' '.join(eval(i)) for i in df['tokens'].to_list()]
    tfidf = TfidfVectorizer(ngram_range=(1, 3))
    x = tfidf.fit_transform(contents)
    model = LatentDirichletAllocation(n_components=n_components, random_state=42)
    model.fit(x)
    featute_names = tfidf.get_feature_names()
    rows = []
    for topic in model.components_:
        topwords = [featute_names[i] for i in topic.argsort()[: -top_n - 1:-1]]
        rows.append(topwords)
    for idx, row in enumerate(rows):
        print(f'topic :{idx + 1}')
        print(row)

print('positive')
topic_analysis(pos_df, 10, 10)
print('neutrality')
topic_analysis(neu_df, 10, 10)
print('negtive')
topic_analysis(neg_df, 10, 10)
# Out:
# positive
# topic :1
# ['china', 'welcome china', 'welcome', 'chinese', 'world', 'happy', 'us', 'good', 'great', 'good china']
# topic :2
# ['china', 'chinese', 'best', 'autumn', 'love', 'new', 'album', 'year', 'thank', 'beauty autumn']
# topic :3
# ['new year', 'chinese new year', 'chinese new', 'happy chinese new', 'happy chinese', 'year', 'new', 'happy', 'chinese', 'china']
# topic :4
# ['china', 'best', 'kpop', 'best selling', 'selling', 'chinese', 'selling kpop', 'best selling kpop', 'china year', 'champ']
# topic :5
# ['things happening china', 'happening china', 'things happening', 'happening', 'china', 'things', 'incredible things', 'incredible things happening', 'incredible', 'chinese']
# topic :6
# ['chinese', 'china', 'love', 'like', 'one', 'album', 'made', 'first', 'thank', 'year']
# topic :7
# ['china', 'chinese', 'best', 'best selling', 'selling', 'year', 'food', 'digital', 'like', 'world']
# topic :8
# ['china', 'chinese', 'new', 'first', 'rank', 'happy', 'us', 'jimin bts', 'congratulations jimin bts', 'jimin bts twt']
# topic :9
# ['china', 'chinese', 'great wall china', 'wall china', 'great wall', 'wall', 'great', 'one', 'world', 'people']
# topic :10
# ['china', 'chinese', 'happy', 'thank', 'india', 'right', 'thank china', 'year', 'best', 'love']
# neutrality
# topic :1
# ['china', 'chinese', 'us', 'stealthgirl', 'india', 'new', 'world', 'russia', 'years', 'covid']
# topic :2
# ['china', 'chinese', 'us', 'iaponomarenko', 'russia', 'new', 'india', 'world', 'thai', 'italy']
# topic :3
# ['elonmusk', 'china', 'chinese', 'potus', 'us', 'biden', 'taiwan', 'russia', 'covid', 'new']
# topic :4
# ['china', 'chinese', 'happened', 'week', 'thread', 'week thread', 'us', 'happened china week', 'china week thread', 'china week']
# topic :5
# ['repswalwell', 'china', 'chinese', 'biden', 'us', 'russia', 'india', 'meanwhile', 'meanwhile china', 'trillion']
# topic :6
# ['china', 'chinese', 'us', 'stewartdantec', 'biden', 'india', 'russia', 'year', 'time', 'new']
# topic :7
# ['china', 'chinese', 'kingjames', 'breaking', 'tibet china', 'india', 'us', 'tibet', 'russia', 'jeffbezos']
# topic :8
# ['china', 'chinese', 'ericswalwell', 'ronfilipkowski', 'us', 'india', 'biden', 'russia', 'rahulgandhi', 'aginnt']
# topic :9
# ['china', 'chinese', 'biden', 'us', 'new', 'poster', 'vogue china', 'chinese poster', 'vogue', 'balloon']
# topic :10
# ['china', 'chinese', 'india', 'us', 'new', 'biden', 'russia', 'world', 'one', 'speakerpelosi']
# negtive
# topic :1
# ['china', 'chinese', 'people', 'biden', 'us', 'communist', 'russia', 'government', 'world', 'virus']
# topic :2
# ['china', 'chinese', 'us', 'russia', 'people', 'biden', 'world', 'party', 'virus', 'america']
# topic :3
# ['china', 'chinese', 'us', 'biden', 'like', 'covid', 'russia', 'people', 'world', 'congress']
# topic :4
# ['china', 'chinese', 'communist', 'people', 'covid', 'us', 'biden', 'country', 'party', 'would']
# topic :5
# ['china', 'chinese', 'russia', 'us', 'people', 'biden', 'government', 'covid', 'india', 'like']
# topic :6
# ['china', 'chinese', 'people', 'us', 'trump', 'like', 'covid', 'world', 'india', 'biden']
# topic :7
# ['china', 'chinese', 'us', 'biden', 'people', 'war', 'russia', 'communist', 'trump', 'world']
# topic :8
# ['china', 'chinese', 'us', 'people', 'russia', 'biden', 'covid', 'trump', 'india', 'party']
# topic :9
# ['china', 'chinese', 'us', 'people', 'biden', 'russia', 'covid', 'like', 'military', 'trump']
# topic :10
# ['china', 'chinese', 'biden', 'people', 'us', 'russia', 'world', 'think', 'stop', 'like']

# %%
from read_data import read_csv

# %%
df = read_csv('outputs/chinese_culture_2021-01-01_2023-05-13.csv')

# %%
df.head()
# Out:
#                     UserScreenName         UserName                 Timestamp  \
# 0                    boysenberry45  @boysenberry451  2021-01-01T15:23:35.000Z
# 1                            freya     @hotbruvshit  2021-01-01T00:11:30.000Z
# 2                            Shami       @Shami_Das  2021-01-01T10:17:40.000Z
# 3                  rachel tensions  @joeytalks2much  2021-01-01T00:58:12.000Z
# 4  stan lulu, luobo, laosan, laosi     @refreshxing  2021-01-01T05:36:51.000Z
#
#                                                 Text  \
# 0     boysenberry45\n@boysenberry451\n·\nJan 1, 2021
# 1                freya\n@hotbruvshit\n·\nJan 1, 2021
# 2                  Shami\n@Shami_Das\n·\nJan 1, 2021
# 3   rachel tensions\n@joeytalks2much\n·\nJan 1, 2021
# 4  stan lulu, luobo, laosan, laosi\n@refreshxing\...
#
#                                        Embedded_text Emojis  Comments Likes  \
# 0  In Chinese culture, the Great Egret represents...    NaN       7.0    15
# 1  when ur white parents raised u with chinese cu...    NaN       NaN   NaN
# 2                     Replying to \n@globaltimesnews    NaN       NaN   NaN
# 3  10.) Over The Moon\n\nAmbitious storytelling w...    NaN       1.0   NaN
# 4  Me as non chinese finds this is so amusing, an...    NaN       NaN   NaN
#
#   Retweets                                         Image link  \
# 0      218  ['https://pbs.twimg.com/media/Eqp-WPRXUAIGTEX?...
# 1      NaN  ['https://pbs.twimg.com/media/Eqmu_U7VkAAIboS?...
# 2      NaN                                                 []
# 3      NaN  ['https://pbs.twimg.com/media/Eqm5rQMXAAA-3gN?...
# 4      NaN                                                 []
#
#                                            Tweet URL
# 0  https://twitter.com/boysenberry451/status/1345...
# 1  https://twitter.com/hotbruvshit/status/1344798...
# 2  https://twitter.com/Shami_Das/status/134495091...
# 3  https://twitter.com/joeytalks2much/status/1344...
# 4  https://twitter.com/refreshxing/status/1344880...

# %%
tmp = df.dropna(subset=['Retweets']).reset_index(drop=True)

# %%
def convert_to_int(x):
    x = x.replace(',', '')
    if 'K' in x:
        x = eval(x[:-1]) * 1000
    else:
        return eval(x)

# %%
tmp['Retweets'] = tmp['Retweets'].apply(convert_to_int)

# %%
tmp = tmp[tmp['Retweets'] > 50]

# %%
tmp.to_csv('outputs/chinese_culture_2021-01-01_2023-05-13_retweet_50.csv', index=False)
